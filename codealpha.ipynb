# %%
# import the all packages

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# open data and read the data 

bank_data=pd.read_csv(r"bank.csv",sep=';')
bank_data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# divide the categorical and numerical columns 

cat = bank_data.select_dtypes(include='object').columns
num = bank_data.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
num
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
# count the job count value 

keys=bank_data['job'].value_counts().keys()
values=bank_data['job'].value_counts().values

# %%
keys
# Out:
# Index(['management', 'blue-collar', 'technician', 'admin.', 'services',
#        'retired', 'self-employed', 'entrepreneur', 'unemployed', 'housemaid',
#        'student', 'unknown'],
#       dtype='object', name='job')

# %%
values
# Out:
# array([969, 946, 768, 478, 417, 230, 183, 168, 128, 112,  84,  38])

# %%
# zip the both column and create the frequancy table using the Dataframe

bank_fr=pd.DataFrame(zip(keys,values),
                    columns=['Label','Count'])
bank_fr
# Out:
#             Label  Count
# 0      management    969
# 1     blue-collar    946
# 2      technician    768
# 3          admin.    478
# 4        services    417
# 5         retired    230
# 6   self-employed    183
# 7    entrepreneur    168
# 8      unemployed    128
# 9       housemaid    112
# 10        student     84
# 11        unknown     38

# %%
# # make bar chart using frequancy tabel
plt.figure(figsize=(18,8))
plt.bar(keys,values)
plt.savefig('practice_bank_bar.jpg')
# plt.show()

# %%
# make the pie chart using frequancy tabel
plt.pie(values,
       labels=keys,
       explode=([0.1 for i in range(len(keys))]),
       autopct="%0.2f%%"
        )
plt.figure(figsize=(10,4))
plt.savefig('practice_bank_pie.jpg')
plt.show()

# %%
# create the folder using the import os 

import os 

folder_name='codealpha_bank_data_folder'        # take the folder name 
os.makedirs(folder_name,exist_ok=True)         # this folder save the makedirs

cwd=os.getcwd()                                # this is the current workking directory

file_name='codealpha_bank_data.csv'             # all data are save into this file 

path=os.path.join(cwd,folder_name,file_name)   # join the all  folder in one dir

bank_fr.to_csv(path,index=False)

# %%
# save te all frequancy tables and one folder 
for i in cat: 
    keys=bank_data[i].value_counts().keys()
    values=bank_data[i].value_counts().values

    bank_fr=pd.DataFrame(zip(keys,values),
                        columns=['Labes','count'])

    folder_name='codealpha all frequncy table'
    os.makedirs(folder_name,exist_ok=True)
    
    cwd=os.getcwd()
    file_name=f'{i}.csv'
    path=os.path.join(cwd,folder_name,file_name)
    path

    bank_fr.to_csv(path,index=True)

# %%
# save the all bar chart
for i in cat:
    keys=bank_data[i].value_counts().keys()
    values=bank_data[i].value_counts().values

    bank_fr=pd.DataFrame(zip(keys,values),
                        columns=['Labes','count'])

    folder_name='codealpha_all_bank_bar_chart'
    os.makedirs(folder_name,exist_ok=True)
    
    cwd=os.getcwd()
    
    file_name=f'{i}.jpg'
    path=os.path.join(cwd,folder_name,file_name)
     
    plt.figure(figsize=(18,5))
    plt.bar(keys,values)
    plt.savefig(path)
    plt.show()

# %%
for i in cat:
    keys=bank_data[i].value_counts().keys()
    values=bank_data[i].value_counts().values

    bank_fr=pd.DataFrame(zip(keys,values),
                        columns=['Labes','Count'])
    folder_name='codealpha_all_bank_pie_charts'
    os.makedirs(folder_name,exist_ok=True)

    cwd=os.getcwd()

    file_name=f'{i}.jpg'
    path=os.path.join(cwd,folder_name,file_name)

    plt.pie(values,
           labels=keys,
           explode=[0.1 for i in range(len(keys))],
           autopct='%0.2f%%'
           )
    plt.show()

    plt.savefig(path)

# %%
plt.figure(figsize=(29,20))
for i in range(1,len(cat)):
    keys=bank_data[cat[i]].value_counts().keys()    
    values=bank_data[cat[i]].value_counts().values  

    plt.subplot(4,4,i).bar(keys,values)               # i :number
    plt.title(f'{cat[i]}_bar_chart')
    plt.suptitle('Barchart')                          # plt.bar(keys,values)
    plt.savefig('codealpha_bank_bar.jpg')

# %%
plt.figure(figsize=(29,20))
for i in range(1,len(cat)):
    keys=bank_data[cat[i]].value_counts().keys() 
    values=bank_data[cat[i]].value_counts().values
    plt.subplot(3,3,i).pie(values,
                         labels=keys,
                        explode=[0.1 for i in range(len(keys))],
                        autopct='%0.2f%%')
    
    plt.title(f'{cat[i]}_bar_chart')
    plt.suptitle('Barchart')                         
    plt.savefig('codealpha_all_bank_pie.jpg')

# %%
plt.figure(figsize=(25,40))
idx = 1
a = 1
for i in range(len(cat)):
    if cat[i] == 'emp no':
        continue

    keys = bank_data[cat[i]].value_counts().keys()
    values = bank_data[cat[i]].value_counts().values
    plt.suptitle('TP')
    ax1 = plt.subplot(8,4,idx)
    ax1.bar(keys, values)
    plt.title(cat[i])

    ax2 = plt.subplot(8,4,idx+a)
    ax2.pie(x=values, labels = keys,
           explode = [0.1]*len(keys))
    plt.title(cat[i])

    idx += 2

plt.show()

# %%
plt.figure(figsize=(10,20))
for i in range(1,len(cat)):
    keys=bank_data[cat[i]].value_counts().keys()    
    values=bank_data[cat[i]].value_counts().values  

    plt.subplot(9,1,i).bar(keys,values)              # i :number
    plt.title(f'{cat[i]}_bar_chart')
    plt.suptitle('Barchart')                          # plt.bar(keys,values)
    plt.savefig('codealpha_bank_bar.jpg')

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
saur = pd.read_csv(r"bank.csv",sep=";")

# %%
saur
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
cat = saur.select_dtypes(include='object').columns
num = saur.select_dtypes(exclude='object').columns

# %%
keys = saur['contact'].value_counts().keys()
values = saur['contact'].value_counts().values

saur_df=pd.DataFrame(zip(keys,values),
                    columns=['contact','number'])


plt.figure(figsize=(4,5))
col = ['yellow','blue','black']
plt.bar(keys,values,color=col)
plt.show()

# %%
plt.pie(values,
       labels=keys,
       explode=[0.1 for i in range(len(keys))],
        autopct='%0.2f%%'
       )
plt.show()

# %%
import os

# %%
folder_name = 'codealpha.csv'
os.makedirs(folder_name,exist_ok=True)

cwd = os.getcwd()

file_name = 'codealpha.csv'

path = os.path.join(cwd,folder_name,file_name)

saur.to_csv(path,index=False)

# %%
folder_name = 'codealpha_bar'
os.makedirs(folder_name,exist_ok=True)


plt.bar(keys,values)
plt.show()

cwd = os.getcwd()

file_name = 'codealpha_bar.csv'

path = os.path.join(cwd,folder_name,file_name)

# plt.bar(keys,values)
# plt.show()

# %%
bank_data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_data['marital'].value_counts()
# Out:
# marital
# married     2797
# single      1196
# divorced     528
# Name: count, dtype: int64

# %%
bank_data['job']=='marital'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520    False
# Name: job, Length: 4521, dtype: bool

# %%
con1 = bank_data['job'] == 'unemployed'
con2 = bank_data['marital'] == 'married'
con = bank_data[con1 & con2]
len(con)
# Out:
# 75

# %%
job=bank_data['job'].unique()
print(len(job))
job
# Out:
# 12
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
con1 = bank_data['job']=='unemployed'
con2 = bank_data['marital'] == 'married'
con = bank_data[con1 & con2]
len(con)
# Out:
# 75

# %%
job_labels=bank_data['job'].unique()
married_list=[]
for i in job_labels:
    
    con1 = bank_data['job'] == i
    con2 = bank_data['marital'] == 'married'
    con = con1 & con2
    married_list.append(len(bank_data[con]))
married_list
# Out:
# [75, 236, 557, 693, 127, 411, 132, 266, 10, 84, 176, 30]

# %%
job_labels=bank_data['job'].unique()
married_list=[]
single_list=[]
for i in job_labels:
    
    con1 = bank_data['job'] == i
    con2 = bank_data['marital'] == 'married'
    con3 = bank_data['marital'] == 'single'
    married_con= con1 & con2
    single_con=con1&con3
    married_list.append(len(bank_data[married_con]))
    single_list.append(len(bank_data[single_con]))
married_con,single_list
pd.DataFrame(zip(married_list,single_list),
            index=job_labels,
            columns=['married','single'])
# Out:
#                married  single
# unemployed          75      31
# services           236     119
# management         557     293
# blue-collar        693     174
# self-employed      127      41
# technician         411     268
# entrepreneur       132      20
# admin.             266     143
# student             10      74
# housemaid           84      15
# retired            176      11
# unknown             30       7

# %%
con1 = bank_data['marital'] == 'married'
bank_data[con].groupby('job').size()
# Out:
# job
# unknown    30
# dtype: int64

# %%
con1 = bank_data['job']
con2 = bank_data['marital']
pd.crosstab(con1,con2)
# Out:
# marital        divorced  married  single
# job
# admin.               69      266     143
# blue-collar          79      693     174
# entrepreneur         16      132      20
# housemaid            13       84      15
# management          119      557     293
# retired              43      176      11
# self-employed        15      127      41
# services             62      236     119
# student               0       10      74
# technician           89      411     268
# unemployed           22       75      31
# unknown               1       30       7

# %%
con1 = bank_data['job']
con2 = bank_data['marital']
r1=pd.crosstab(con2,con1)

# %%
r1.plot(kind='bar')
# Out:
# <Axes: xlabel='marital'>

# %%
bank_data.corr(numeric_only=True)
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
plt.figure(figsize=(15,8))
corr=bank_data.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
col1=bank_data['age']   
col2=bank_data['balance']
col3=bank_data['pdays']
plt.subplot(1,2,1).scatter(col1,col2)
plt.subplot(1,2,2).scatter(col1,col3)

# %% [markdown]
# # Method -1 : Map

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 


bank_data = pd.read_csv(r"bank.csv",sep=';')
cat = bank_data.select_dtypes(include='object').columns
num = bank_data.select_dtypes(exclude='object').columns

# %%
bank_data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_data['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
# bank_data = pd.read_csv(r"bank.csv") 
# labels = bank_data['job'].unique()
# d = {}
# for i in range(len(labels)):
#     keys = labels[i]
#     d[keys]=i

# d

# %%
# # we use sorted to alphabetical order 

# labels = sorted(bank_data['job'].unique())
# d = {}
# for i in range(len(labels)):
#     keys = labels[i]
#     d[keys]=i

# d

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path= r"bank.csv"

# %%
my=pd.read_csv(path,sep=';')

# %%
my
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# devide the data into tew oarts in the categorical and numerical 


cat=my.select_dtypes(include='object').columns
num=my.select_dtypes(exclude='object').columns

# %%
keys=my['job'].value_counts().keys()
value=my['job'].value_counts().values

# %%
keys
# Out:
# Index(['management', 'blue-collar', 'technician', 'admin.', 'services',
#        'retired', 'self-employed', 'entrepreneur', 'unemployed', 'housemaid',
#        'student', 'unknown'],
#       dtype='object', name='job')

# %%
value
# Out:
# array([969, 946, 768, 478, 417, 230, 183, 168, 128, 112,  84,  38])

# %%
my_df=pd.DataFrame(zip(keys,value),
                  columns=["count","value"])

# %%
my_df
# Out:
#             count  value
# 0      management    969
# 1     blue-collar    946
# 2      technician    768
# 3          admin.    478
# 4        services    417
# 5         retired    230
# 6   self-employed    183
# 7    entrepreneur    168
# 8      unemployed    128
# 9       housemaid    112
# 10        student     84
# 11        unknown     38

# %%
plt.figure(figsize=(18,7))
plt.bar(keys,value)
plt.show()

# %%
plt.pie(value,
       labels=keys,
       explode=([0.1 for i in range(len(keys))]),
       autopct="%0.2f%%",
       startangle=45)
plt.show()

# %%
# create the folder using the os

# %%
import os

# %%
keys=my['job'].value_counts().keys()   # keys
value=my['job'].value_counts().values   # values


my_df=pd.DataFrame(zip(keys,value))   # create the dataframe 

folder_name = "my folder"                 
os.makedirs(folder_name,exist_ok=True)     

cwd = os.getcwd()

new_dir=os.path.join(cwd,folder_name)

file_name="my_practice.csv"

path=os.path.join(folder_name,file_name)

my_df.to_csv(path)

# %%
for i in cat:
    keys=my[i].value_counts().keys()
    value=my[i].value_counts().values

    my_df=pd.DataFrame(zip(keys,value))

    folder_name = "codealpha_all_fr_table"
    os.makedirs(folder_name,exist_ok=True)

    cwd = os.getcwd()

    new_dir = os.path.join(cwd,folder_name)

    file_name = (f"{i}.csv")

    path = os.path.join(new_dir,file_name)

    my_df.to_csv(path)

# %%
for i in cat:
    keys = my[i].value_counts().keys()
    value = my[i].value_counts().values

    my_df=pd.DataFrame(zip(keys,value),
                      columns=["label","count"])


    folder_name = "codealpha_my_charts"
    os.makedirs(folder_name,exist_ok=True)

    cwd = os.getcwd()

    new_dir=os.path.join(cwd,folder_name)

    file_name = f"{i}.jpg"

    path=os.path.join(folder_name,file_name)


    
    plt.bar(keys,value)
    plt.figure(figsize=(18,5))
    plt.savefig(path)
    plt.show()

# %%
for i in cat:
    keys = my[i].value_counts().keys()
    value = my[i].value_counts().values

    my_df = pd.DataFrame(zip(keys,value),
                        columns=["label","count"])

    folder_name = "codealpha_my_pie"
    os.makedirs(folder_name,exist_ok=True)

    cwd = os.getcwd()

    new_dir = os.path.join(cwd,folder_name)

    file_name = f"{i}.jpg"

    path=os.path.join(folder_name,file_name)

    plt.pie(value,
           labels=keys,
           explode=([0.1 for i in range(len(keys))]),
           autopct="%0.2f%%",
           )

    plt.savefig(path)

    plt.show()

# %%
plt.figure(figsize=(18,10))
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
plt.figure(figsize=(29,20))
for i in range(1,len(cat)):
    keys=my[cat[i]].value_counts().keys()    
    values=my[cat[i]].value_counts().values  

    plt.subplot(4,4,i).bar(keys,values)              # i :number
    plt.title(f'{cat[i]}_bar_chart')
    plt.suptitle('Barchart')                          # plt.bar(keys,values)
    plt.savefig('bank_bar.jpg')

# %%
plt.figure(figsize=(28,20))
for i in range(1,len(cat)):
    keys = my[cat[i]].value_counts().keys()
    value = my[cat[i]].value_counts().values

    plt.subplot(4,4,i).bar(keys,value)
    plt.title(f"{cat[i]}_bar") 
    plt.suptitle("all_bar")

# %%
my
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...
